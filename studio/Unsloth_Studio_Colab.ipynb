# %% [markdown]
# <a href="https://colab.research.google.com/github/norta92/.dotfiles---edex/blob/main/studio/Unsloth_Studio_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth Studio on your local device, follow [our guide](https://unsloth.ai/docs/new/unsloth-studio/install). Unsloth Studio is licensed [AGPL-3.0](https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0).
#
# ### Unsloth Studio
#
# Train and run open models with [**Unsloth Studio**](https://unsloth.ai/docs/new/unsloth-studio/start). NEW! Installation should now only take 2 mins!
#
#
# We are actively working on making Unsloth Studio install on Colab T4 GPUs faster.
#
# [Features](https://unsloth.ai/docs/new/unsloth-studio#features) • [Quickstart](https://unsloth.ai/docs/new/unsloth-studio/start) • [Data Recipes](https://unsloth.ai/docs/new/unsloth-studio/data-recipe) • [Studio Chat](https://unsloth.ai/docs/new/unsloth-studio/chat) • [Export](https://unsloth.ai/docs/new/unsloth-studio/export)

# %% [markdown]
# <p align="left"><img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/studio%20github%20landscape%20colab%20display.png" width="600"></p>

# %% [markdown]
# ### Setup: Clone repo and run setup

# %%
# !git clone --depth 1 --branch main https://github.com/unslothai/unsloth.git
# %cd /content/unsloth
# !chmod +x studio/setup.sh && ./studio/setup.sh

# %% [markdown]
# ### Start Unsloth Studio

# %%
import sys, time
sys.path.insert(0, "/content/unsloth/studio/backend")
from colab import start
start()
# Out:
# 2026-03-29 22:09:15 [info     ] 🦥 Starting Unsloth Studio...
# 2026-03-29 22:09:15 [info     ]    Loading backend...
# 2026-03-29 22:09:15 [info     ]    Starting server...
# INFO:     Started server process [21575]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8888 (Press CTRL+C to quit)
# Hardware detected: CPU (no GPU backend available)
# {"timestamp": "2026-03-29T22:09:29.994958Z", "level": "info", "event": "Pre-caching helper GGUF: unsloth/Qwen3.5-4B-GGUF/Qwen3.5-4B-UD-Q4_K_XL.gguf"}
# {"timestamp": "2026-03-29T22:09:30.027617Z", "level": "info", "event": "Helper GGUF cached: 1 file(s)"}
# {"timestamp": "2026-03-29T22:09:32.106560Z", "level": "info", "event": "   Server started!"}
#     <div style="display: inline-block; padding: 20px; background: #ffffff; border: 2px solid #000000;
#                 border-radius: 12px; margin: 10px 0; font-family: system-ui, -apple-system, sans-serif;">
#         <h2 style="color: #000000; margin: 0 0 12px 0; font-size: 26px; font-weight: 800;
#                    display: flex; align-items: center; gap: 12px;">
#             <img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/unsloth-gem.png"
#                  height="48" style="display:block;">
#             Unsloth Studio is Ready!
#         </h2>
#         <a href="https://8888-m-s-kkb-use4a2-bf6vjz4lb2aa-a.us-east4-2.prod.colab.dev" target="_blank"
#            style="display: inline-flex; align-items: center; gap: 10px; padding: 14px 28px;
#                   background: #000000; color: white; text-decoration: none; border-radius: 8px;
#                   font-weight: 800; font-size: 16px;">
#             <svg xmlns="http://www.w3.org/2000/svg" width="18" height="18" viewBox="0 0 24 24" fill="white"><polygon points="5,3 19,12 5,21"/></svg>
#             Open Unsloth Studio
#         </a>
#         <p style="color: #333333; margin: 16px 0 0 0; font-size: 13px; font-family: monospace;">
#             https://8888-m-...
#         </p>
#     </div>

# %%
from google.colab import output
output.serve_kernel_port_as_iframe(8888, height = 1200, width = "100%")
for _ in range(10000): time.sleep(300), print("=", end = "")
# Out:
# {"timestamp": "2026-03-29T22:09:52.341839Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.96}
# {"timestamp": "2026-03-29T22:09:52.601927Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 1.79}
# {"timestamp": "2026-03-29T22:10:00.184713Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 1.59}
# {"timestamp": "2026-03-29T22:10:00.571292Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 4.06}
# {"timestamp": "2026-03-29T22:10:00.797462Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.51}
# {"timestamp": "2026-03-29T22:10:14.499820Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/login", "status_code": 200, "process_time_ms": 169.87}
# {"timestamp": "2026-03-29T22:10:15.313458Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.89}
# {"timestamp": "2026-03-29T22:10:16.210317Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.21}
# {"timestamp": "2026-03-29T22:10:18.061084Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/refresh", "status_code": 200, "process_time_ms": 3.52}
# {"timestamp": "2026-03-29T22:10:19.923959Z", "level": "info", "event": "Found 0 trained LoRA adapters in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-03-29T22:10:19.926424Z", "level": "info", "event": "Found 0 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-03-29T22:10:19.932989Z", "level": "info", "event": "InferenceOrchestrator initialized (subprocess mode)"}
# {"timestamp": "2026-03-29T22:10:20.124706Z", "level": "info", "event": "Top GGUF models: ['unsloth/Qwen3.5-35B-A3B-GGUF', 'unsloth/Qwen3.5-9B-GGUF', 'unsloth/Qwen3.5-27B-GGUF', 'unsloth/Qwen3.5-4B-GGUF', 'unsloth/Qwen3.5-122B-A10B-GGUF', 'unsloth/gpt-oss-20b-GGUF', 'unsloth/Qwen3.5-0.8B-GGUF', 'unsloth/Qwen3-Coder-Next-GGUF', 'unsloth/GLM-4.7-Flash-GGUF', 'unsloth/Qwen3.5-2B-GGUF', 'unsloth/LTX-2.3-GGUF', 'unsloth/Nemotron-3-Nano-30B-A3B-GGUF', 'unsloth/Qwen3.5-397B-A17B-GGUF', 'unsloth/Qwen3-Coder-30B-A3B-Instruct-GGUF', 'unsloth/Qwen3-VL-4B-Instruct-GGUF', 'unsloth/gemma-3-27b-it-GGUF', 'unsloth/gpt-oss-120b-GGUF', 'unsloth/Qwen-Image-Edit-2511-GGUF', 'unsloth/Llama-3.2-1B-Instruct-GGUF', 'unsloth/gemma-3-12b-it-GGUF', 'unsloth/DeepSeek-R1-Distill-Qwen-1.5B-GGUF', 'unsloth/NVIDIA-Nemotron-3-Super-120B-A12B-GGUF', 'unsloth/Qwen3-4B-Instruct-2507-GGUF', 'unsloth/Qwen3-4B-GGUF', 'unsloth/gemma-3-270m-it-GGUF', 'unsloth/Qwen2.5-VL-7B-Instruct-GGUF', 'unsloth/gemma-3-4b-it-GGUF', 'unsloth/MiniMax-M2.5-GGUF', 'unsloth/DeepSeek-R1-0528-Qwen3-8B-GGUF', 'unsloth/Qwen3-VL-30B-A3B-Instruct-GGUF', 'unsloth/DeepSeek-R1-Distill-Qwen-14B-GGUF', 'unsloth/GLM-4.6V-Flash-GGUF', 'unsloth/Qwen3.5-35B-A3B-Experiments-GGUF', 'unsloth/Qwen3-0.6B-GGUF', 'unsloth/Qwen3-VL-8B-Instruct-GGUF']"}
# {"timestamp": "2026-03-29T22:10:20.127116Z", "level": "info", "event": "Top hub models: ['unsloth/GLM-4.7-Flash-FP8-Dynamic', 'unsloth/mistral-7b-v0.3-bnb-4bit', 'unsloth/Meta-Llama-3.1-8B-Instruct', 'unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit', 'unsloth/DeepSeek-OCR-2', 'unsloth/Qwen3-0.6B', 'unsloth/gpt-oss-20b', 'unsloth/Llama-3.1-8B-Instruct', 'unsloth/Qwen3-0.6B-unsloth-bnb-4bit', 'unsloth/Llama-3.2-1B-Instruct', 'unsloth/Qwen3-14B-unsloth-bnb-4bit', 'unsloth/Qwen2.5-7B-Instruct-bnb-4bit', 'unsloth/gpt-oss-20b-unsloth-bnb-4bit', 'unsloth/Llama-3.2-3B-Instruct', 'unsloth/Qwen3.5-9B', 'unsloth/Qwen3-1.7B-unsloth-bnb-4bit', 'unsloth/Qwen3.5-4B', 'unsloth/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit', 'unsloth/Qwen2.5-7B', 'unsloth/GLM-4.7-Flash', 'unsloth/Qwen2.5-3B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen3.5-2B', 'unsloth/gpt-oss-120b-BF16', 'unsloth/Qwen2-7B', 'unsloth/Qwen3-8B-unsloth-bnb-4bit', 'unsloth/gpt-oss-20b-BF16', 'unsloth/Qwen3-4B-Base', 'unsloth/Llama-3.2-1B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen3.5-0.8B', 'unsloth/Qwen3-4B', 'unsloth/Llama-3.2-3B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen3-8B', 'unsloth/Qwen2.5-7B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen3-4B-bnb-4bit', 'unsloth/Qwen2.5-7B-Instruct', 'unsloth/llama-3-8b-bnb-4bit', 'unsloth/Qwen3-4B-unsloth-bnb-4bit', 'unsloth/DeepSeek-V3-0324-BF16', 'unsloth/Qwen3-VL-4B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen3-32B-bnb-4bit']"}
# {"timestamp": "2026-03-29T22:10:20.135589Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 217.47}
# {"timestamp": "2026-03-29T22:10:20.140197Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 221.58}
# {"timestamp": "2026-03-29T22:10:20.156896Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 11.57}
# {"timestamp": "2026-03-29T22:10:20.159772Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 14.23}
# {"timestamp": "2026-03-29T22:10:20.267310Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.23}
# {"timestamp": "2026-03-29T22:10:34.294124Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.69}
# {"timestamp": "2026-03-29T22:10:51.621501Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 8.88}
# {"timestamp": "2026-03-29T22:10:51.698298Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 2.92}
# {"timestamp": "2026-03-29T22:10:51.707230Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 2.06}
# {"timestamp": "2026-03-29T22:10:51.715664Z", "level": "info", "event": "Found 0 trained LoRA adapters in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-03-29T22:10:51.717137Z", "level": "info", "event": "Found 0 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-03-29T22:10:51.718966Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 4.85}
# {"timestamp": "2026-03-29T22:11:07.226209Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 4.74}
# {"timestamp": "2026-03-29T22:11:07.245893Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-gguf", "status_code": 200, "process_time_ms": 16.07}
# {"timestamp": "2026-03-29T22:11:07.248912Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-models", "status_code": 200, "process_time_ms": 8.28}
# {"timestamp": "2026-03-29T22:11:10.118619Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 2.93}
# {"timestamp": "2026-03-29T22:11:12.637284Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-variants", "status_code": 200, "process_time_ms": 84.84}
# {"timestamp": "2026-03-29T22:11:14.142546Z", "level": "info", "event": "Detected remote GGUF repo 'unsloth/phi-4-mini-reasoning-gguf', variant=UD-Q4_K_XL, vision=False"}
# {"timestamp": "2026-03-29T22:11:14.145797Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/validate", "status_code": 200, "process_time_ms": 311.29}
# {"timestamp": "2026-03-29T22:11:14.663117Z", "level": "info", "event": "Detected remote GGUF repo 'unsloth/phi-4-mini-reasoning-gguf', variant=UD-Q4_K_XL, vision=False"}
# {"timestamp": "2026-03-29T22:11:14.837645Z", "level": "info", "event": "GGUF download: 2.3 GB needed, 77.3 GB free on disk"}
# {"timestamp": "2026-03-29T22:11:14.838691Z", "level": "info", "event": "Resolving GGUF: unsloth/phi-4-mini-reasoning-gguf/Phi-4-mini-reasoning-UD-Q4_K_XL.gguf"}
# {"timestamp": "2026-03-29T22:11:14.888429Z", "level": "info", "event": "GGUF resolved from cache: /root/.cache/huggingface/hub/models--unsloth--phi-4-mini-reasoning-gguf/snapshots/6b9cfad9419cad66996ad42ebddbff9b34446479/Phi-4-mini-reasoning-UD-Q4_K_XL.gguf"}
# {"timestamp": "2026-03-29T22:11:15.197242Z", "level": "info", "event": "GGUF metadata: context_length=131072"}
# {"timestamp": "2026-03-29T22:11:15.198212Z", "level": "info", "event": "GGUF metadata: chat_template=568 chars"}
# {"timestamp": "2026-03-29T22:11:15.208717Z", "level": "info", "event": "GGUF size: 2.3 GB, est. KV cache: 16.0 GB, context: 131072, GPUs free: [], selected: None, fit: True"}
# {"timestamp": "2026-03-29T22:11:15.209626Z", "level": "info", "event": "Starting llama-server: /root/.unsloth/llama.cpp/llama-server -m /root/.cache/huggingface/hub/models--unsloth--phi-4-mini-reasoning-gguf/snapshots/6b9cfad9419cad66996ad42ebddbff9b34446479/Phi-4-mini-reasoning-UD-Q4_K_XL.gguf --port 40357 -c 131072 --parallel 1 --flash-attn on --fit on --jinja"}
# {"timestamp": "2026-03-29T22:11:43.781943Z", "level": "error", "event": "Error loading model: [Errno 104] Connection reset by peer", "exc_info": true}
# {"timestamp": "2026-03-29T22:11:43.783764Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/load", "status_code": 500, "process_time_ms": 29231.73}
# {"timestamp": "2026-03-29T22:12:03.969275Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 20.03}
# {"timestamp": "2026-03-29T22:12:06.364761Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-variants", "status_code": 200, "process_time_ms": 74.53}
# {"timestamp": "2026-03-29T22:12:08.878552Z", "level": "info", "event": "Detected remote GGUF repo 'unsloth/phi-4-mini-reasoning-gguf', variant=UD-Q4_K_XL, vision=False"}
# {"timestamp": "2026-03-29T22:12:08.880164Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/validate", "status_code": 200, "process_time_ms": 93.33}
# {"timestamp": "2026-03-29T22:12:09.285957Z", "level": "info", "event": "Detected remote GGUF repo 'unsloth/phi-4-mini-reasoning-gguf', variant=UD-Q4_K_XL, vision=False"}
# {"timestamp": "2026-03-29T22:12:09.389633Z", "level": "info", "event": "GGUF download: 2.3 GB needed, 77.3 GB free on disk"}
# {"timestamp": "2026-03-29T22:12:09.390563Z", "level": "info", "event": "Resolving GGUF: unsloth/phi-4-mini-reasoning-gguf/Phi-4-mini-reasoning-UD-Q4_K_XL.gguf"}
# {"timestamp": "2026-03-29T22:12:09.439506Z", "level": "info", "event": "GGUF resolved from cache: /root/.cache/huggingface/hub/models--unsloth--phi-4-mini-reasoning-gguf/snapshots/6b9cfad9419cad66996ad42ebddbff9b34446479/Phi-4-mini-reasoning-UD-Q4_K_XL.gguf"}
# {"timestamp": "2026-03-29T22:12:09.617688Z", "level": "info", "event": "GGUF metadata: context_length=131072"}
# {"timestamp": "2026-03-29T22:12:09.620334Z", "level": "info", "event": "GGUF metadata: chat_template=568 chars"}
# {"timestamp": "2026-03-29T22:12:09.633034Z", "level": "info", "event": "GGUF size: 2.3 GB, est. KV cache: 16.0 GB, context: 131072, GPUs free: [], selected: None, fit: True"}
# {"timestamp": "2026-03-29T22:12:09.634738Z", "level": "info", "event": "Starting llama-server: /root/.unsloth/llama.cpp/llama-server -m /root/.cache/huggingface/hub/models--unsloth--phi-4-mini-reasoning-gguf/snapshots/6b9cfad9419cad66996ad42ebddbff9b34446479/Phi-4-mini-reasoning-UD-Q4_K_XL.gguf --port 42755 -c 131072 --parallel 1 --flash-attn on --fit on --jinja"}
# {"timestamp": "2026-03-29T22:12:35.969337Z", "level": "error", "event": "Error loading model: [Errno 104] Connection reset by peer", "exc_info": true}
# {"timestamp": "2026-03-29T22:12:35.970682Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/load", "status_code": 500, "process_time_ms": 26774.87}
# ={"timestamp": "2026-03-29T22:16:18.000914Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-models", "status_code": 200, "process_time_ms": 53.82}
# {"timestamp": "2026-03-29T22:16:18.011595Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-gguf", "status_code": 200, "process_time_ms": 7.82}
# {"timestamp": "2026-03-29T22:16:19.404904Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-variants", "status_code": 200, "process_time_ms": 134.84}
# {"timestamp": "2026-03-29T22:16:21.819183Z", "level": "info", "event": "Detected remote GGUF repo 'unsloth/phi-4-mini-reasoning-gguf', variant=UD-Q4_K_XL, vision=False"}
# {"timestamp": "2026-03-29T22:16:21.938524Z", "level": "info", "event": "GGUF download: 2.3 GB needed, 77.3 GB free on disk"}
# {"timestamp": "2026-03-29T22:16:21.939592Z", "level": "info", "event": "Resolving GGUF: unsloth/phi-4-mini-reasoning-gguf/Phi-4-mini-reasoning-UD-Q4_K_XL.gguf"}
# {"timestamp": "2026-03-29T22:16:21.984208Z", "level": "info", "event": "GGUF resolved from cache: /root/.cache/huggingface/hub/models--unsloth--phi-4-mini-reasoning-gguf/snapshots/6b9cfad9419cad66996ad42ebddbff9b34446479/Phi-4-mini-reasoning-UD-Q4_K_XL.gguf"}
# {"timestamp": "2026-03-29T22:16:22.155985Z", "level": "info", "event": "GGUF metadata: context_length=131072"}
# {"timestamp": "2026-03-29T22:16:22.157361Z", "level": "info", "event": "GGUF metadata: chat_template=568 chars"}
# {"timestamp": "2026-03-29T22:16:22.166163Z", "level": "info", "event": "GGUF size: 2.3 GB, est. KV cache: 16.0 GB, context: 131072, GPUs free: [], selected: None, fit: True"}
# {"timestamp": "2026-03-29T22:16:22.167329Z", "level": "info", "event": "Starting llama-server: /root/.unsloth/llama.cpp/llama-server -m /root/.cache/huggingface/hub/models--unsloth--phi-4-mini-reasoning-gguf/snapshots/6b9cfad9419cad66996ad42ebddbff9b34446479/Phi-4-mini-reasoning-UD-Q4_K_XL.gguf --port 42039 -c 131072 --parallel 1 --flash-attn on --fit on --jinja"}
# {"timestamp": "2026-03-29T22:16:48.343608Z", "level": "error", "event": "Error loading model: [Errno 104] Connection reset by peer", "exc_info": true}
# {"timestamp": "2026-03-29T22:16:48.345395Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/load", "status_code": 500, "process_time_ms": 26617.12}
# {"timestamp": "2026-03-29T22:16:48.647422Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-variants", "status_code": 200, "process_time_ms": 87.2}
# {"timestamp": "2026-03-29T22:16:48.949626Z", "level": "info", "event": "Detected remote GGUF repo 'unsloth/qwen3.5-4b-gguf', variant=UD-Q4_K_XL, vision=True"}
# {"timestamp": "2026-03-29T22:16:49.027044Z", "level": "info", "event": "GGUF download: 2.7 GB needed, 77.3 GB free on disk"}
# {"timestamp": "2026-03-29T22:16:49.028119Z", "level": "info", "event": "Resolving GGUF: unsloth/qwen3.5-4b-gguf/Qwen3.5-4B-UD-Q4_K_XL.gguf"}
# Qwen3.5-4B-UD-Q4_K_XL.gguf:   0%|          | 0.00/2.91G [00:00<?, ?B/s]
# {"timestamp": "2026-03-29T22:16:57.877676Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-gguf", "status_code": 200, "process_time_ms": 211.37}
# {"timestamp": "2026-03-29T22:16:57.896833Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-models", "status_code": 200, "process_time_ms": 203.76}
# {"timestamp": "2026-03-29T22:16:57.902353Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 208.87}
# {"timestamp": "2026-03-29T22:16:58.192496Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 20.45}
# {"timestamp": "2026-03-29T22:17:03.054474Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-variants", "status_code": 200, "process_time_ms": 101.22}
# {"timestamp": "2026-03-29T22:17:04.357431Z", "level": "info", "event": "Detected remote GGUF repo 'unsloth/phi-4-mini-reasoning-gguf', variant=UD-Q4_K_XL, vision=False"}
# {"timestamp": "2026-03-29T22:17:04.361988Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/validate", "status_code": 200, "process_time_ms": 104.51}
# {"timestamp": "2026-03-29T22:17:04.691455Z", "level": "info", "event": "Detected remote GGUF repo 'unsloth/phi-4-mini-reasoning-gguf', variant=UD-Q4_K_XL, vision=False"}
# {"timestamp": "2026-03-29T22:17:04.811535Z", "level": "info", "event": "GGUF download: 2.3 GB needed, 75.0 GB free on disk"}
# {"timestamp": "2026-03-29T22:17:04.819817Z", "level": "info", "event": "Resolving GGUF: unsloth/phi-4-mini-reasoning-gguf/Phi-4-mini-reasoning-UD-Q4_K_XL.gguf"}
# {"timestamp": "2026-03-29T22:17:04.871747Z", "level": "info", "event": "GGUF resolved from cache: /root/.cache/huggingface/hub/models--unsloth--phi-4-mini-reasoning-gguf/snapshots/6b9cfad9419cad66996ad42ebddbff9b34446479/Phi-4-mini-reasoning-UD-Q4_K_XL.gguf"}
# {"timestamp": "2026-03-29T22:17:05.142205Z", "level": "info", "event": "GGUF metadata: context_length=131072"}
# {"timestamp": "2026-03-29T22:17:05.145152Z", "level": "info", "event": "GGUF metadata: chat_template=568 chars"}
# {"timestamp": "2026-03-29T22:17:05.168465Z", "level": "info", "event": "GGUF size: 2.3 GB, est. KV cache: 16.0 GB, context: 131072, GPUs free: [], selected: None, fit: True"}
# {"timestamp": "2026-03-29T22:17:05.169703Z", "level": "info", "event": "Starting llama-server: /root/.unsloth/llama.cpp/llama-server -m /root/.cache/huggingface/hub/models--unsloth--phi-4-mini-reasoning-gguf/snapshots/6b9cfad9419cad66996ad42ebddbff9b34446479/Phi-4-mini-reasoning-UD-Q4_K_XL.gguf --port 60987 -c 131072 --parallel 1 --flash-attn on --fit on --jinja"}
# {"timestamp": "2026-03-29T22:17:08.360477Z", "level": "info", "event": "GGUF downloaded in 19.3s: /root/.cache/huggingface/hub/models--unsloth--qwen3.5-4b-gguf/snapshots/e87f176479d0855a907a41277aca2f8ee7a09523/Qwen3.5-4B-UD-Q4_K_XL.gguf"}
# {"timestamp": "2026-03-29T22:17:08.410949Z", "level": "info", "event": "Downloading mmproj: unsloth/qwen3.5-4b-gguf/mmproj-BF16.gguf"}
# mmproj-BF16.gguf:   0%|          | 0.00/676M [00:00<?, ?B/s]
# {"timestamp": "2026-03-29T22:17:16.187088Z", "level": "info", "event": "GGUF metadata: context_length=262144"}
# {"timestamp": "2026-03-29T22:17:16.188256Z", "level": "info", "event": "GGUF metadata: chat_template=7816 chars"}
# {"timestamp": "2026-03-29T22:17:16.189037Z", "level": "info", "event": "GGUF metadata: model supports reasoning (enable_thinking)"}
# {"timestamp": "2026-03-29T22:17:16.192265Z", "level": "info", "event": "GGUF metadata: model supports tool calling"}
# {"timestamp": "2026-03-29T22:17:35.694478Z", "level": "error", "event": "Error loading model: [Errno 104] Connection reset by peer", "exc_info": true}
# {"timestamp": "2026-03-29T22:17:35.695925Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/load", "status_code": 500, "process_time_ms": 31102.4}
# {"timestamp": "2026-03-29T22:17:35.707433Z", "level": "info", "event": "GGUF size: 2.7 GB, est. KV cache: 20.0 GB, context: 262144, GPUs free: [], selected: None, fit: True"}
# {"timestamp": "2026-03-29T22:17:35.708741Z", "level": "info", "event": "Reasoning model: enable_thinking=False by default"}
# {"timestamp": "2026-03-29T22:17:35.709938Z", "level": "info", "event": "Using mmproj for vision: /root/.cache/huggingface/hub/models--unsloth--qwen3.5-4b-gguf/snapshots/e87f176479d0855a907a41277aca2f8ee7a09523/mmproj-BF16.gguf"}
# {"timestamp": "2026-03-29T22:17:35.710874Z", "level": "info", "event": "Starting llama-server: /root/.unsloth/llama.cpp/llama-server -m /root/.cache/huggingface/hub/models--unsloth--qwen3.5-4b-gguf/snapshots/e87f176479d0855a907a41277aca2f8ee7a09523/Qwen3.5-4B-UD-Q4_K_XL.gguf --port 49989 -c 262144 --parallel 1 --flash-attn on --fit on --jinja --chat-template-kwargs {\"enable_thinking\": false} --mmproj /root/.cache/huggingface/hub/models--unsloth--qwen3.5-4b-gguf/snapshots/e87f176479d0855a907a41277aca2f8ee7a09523/mmproj-BF16.gguf"}

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other resources:
# 1. Looking to use Unsloth locally? Read our [Installation Guide](https://unsloth.ai/docs/get-started/install) for details on installing Unsloth on Windows, Docker, AMD, Intel GPUs.
# 2. Learn how to do Reinforcement Learning with our [RL Guide and notebooks](https://unsloth.ai/docs/get-started/reinforcement-learning-rl-guide).
# 3. Read our guides and notebooks for [Text-to-speech (TTS)](https://unsloth.ai/docs/basics/text-to-speech-tts-fine-tuning) and [vision](https://unsloth.ai/docs/basics/vision-fine-tuning) model support.
# 4. Explore our [LLM Tutorials Directory](https://unsloth.ai/docs/models/tutorials-how-to-fine-tune-and-run-llms) to find dedicated guides for each model.
# 5. Need help with Inference? Read our [Inference & Deployment page](https://unsloth.ai/docs/basics/inference-and-deployment) for details on using vLLM, llama.cpp, Ollama etc.
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
#
#   <b>This notebook is licensed <a href="https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0">AGPL-3.0</a></b>
# </div>
